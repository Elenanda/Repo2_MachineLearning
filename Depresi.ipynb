# %% [markdown]
# <a href="https://colab.research.google.com/github/Elenanda/Repo2_MachineLearning/blob/main/Depresi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load semua library

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
import sklearn.metrics
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load dan overview data

# %%
df.head(50)  # Menampilkan 50 baris pertama
df.tail(50)  # Menampilkan 50 baris terakhir
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 27851  140393  Female  25.0       Varanasi    Student                3.0
# 27852  140395    Male  19.0        Chennai    Student                3.0
# 27853  140400    Male  23.0         Kalyan    Student                2.0
# 27854  140401    Male  23.0         Kalyan    Student                2.0
# 27855  140409    Male  28.0         Nagpur    Student                1.0
# 27856  140413  Female  21.0        Lucknow    Student                1.0
# 27857  140430    Male  32.0      Hyderabad    Student                2.0
# 27858  140438  Female  18.0       Ludhiana    Student                3.0
# 27859  140439  Female  31.0    Vasai-Virar    Student                3.0
# 27860  140444  Female  33.0          Delhi    Student                4.0
# 27861  140448    Male  22.0      Faridabad    Student                5.0
# 27862  140453  Female  21.0      Faridabad    Student                2.0
# ...

# %%
from matplotlib import pyplot as plt
_df_2['Academic Pressure'].plot(kind='hist', bins=20, title='Academic Pressure')
plt.gca().spines[['top', 'right',]].set_visible(False)
